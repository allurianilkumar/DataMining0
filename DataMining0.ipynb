# %% [markdown]
# # Data Mining
#
# ## OBJECTIVES
# * Familiarize yourself with the JupyterLab environment, Markdown and Python
#
# * Familiarize yourself with Github and basic git
#
# * Explore JupyterHub Linux console integrating what you learned in the prior parts of this homework
#
# * Listen to the O'Reilly Data Show Podcast from July 18, 2019: Acquiring and sharing high-quality data with Roger Chen
#
# * Explore Python for data munging and analysis, with an introduction to CSV and Pandas
#
# ## WHAT TO TURN IN
# You are being encouraged to turn the assignment in using the provided
# Jupyter Notebook.  To do so, make a directory in your Lab environment called
# `homework/hw0`.   Put all of your files in that directory.  Then zip that directory,
# rename it with your name as the first part of the filename (e.g. `maull_hw0_files.zip`), then
# download it to your local machine, then upload the `.zip` to Blackboard.
#
# If you do not know how to do this, please ask, or visit one of the many tutorials out there
# on the basics of using zip in Linux.
#
# If you choose not to use the provided notebook, you will still need to turn in a
# `.ipynb` Jupyter Notebook and corresponding files according to the instructions in
# this homework.
#
# ## ASSIGNMENT TASKS
# ### (0%) Familiarize yourself with the JupyterLab environment, Markdown and Python
#
# As stated in the course announcement [Jupyter (https://jupyter.org)](https://jupyter.org) is the
# core platform we will be using in this course and
# is a popular platform for data scientists around the world.  We have a JupyterLab
# setup for this course so that we can operate in a cloud-hosted environment, free from
# some of the resource constraints of running Jupyter on your local machine (though you are free to set
# it up on your own and seek my advice if you desire).
#
# You have been given the information about the  Jupyter environment we have setup for our course, and
# the underlying Python environment will be using is the [Anaconda (https://anaconda.com)](https://anaconda.com)
# distribution.  It is not necessary for this assignment, but you are free to look at the multitude
# of packages installed with Anaconda, though we will not use the majority of them explicitly.
#
# As you will soon find out, Notebooks are an incredibly effective way to mix code with narrative
# and you can create cells that are entirely code or entirely Markdown.  Markdown (MD or `md`) is
# a highly readable text format that allows for easy documentation of text files, while allowing
# for HTML-based rendering of the text in a way that is style-independent.
#
# We will be using Markdown frequently in this course, and you will learn that there are many different
# "flavors" or Markdown.  We will only be using the basic flavor, but you will benefit from exploring
# the "Github flavored" Markdown, though you will not be responsible for using it in this course -- only the
# "basic" flavor.  Please refer to the original course announcement about Markdown.
#
# &#167;  **THERE IS NOTHING TO TURN IN FOR THIS PART.** Play with and become familiar with the basic functions of
# the Lab environment given to you online in the course Blackboard.
#
#
# &#167;  **PLEASE _CREATE A MARKDOWN DOCUMENT_ CALLED `semester_goals.md` WITH 3 SENTENCES/FRAGMENTS THAT
# ANSWER THE FOLLOWING QUESTION:**
#
# * **What do you wish to accomplish this semester in Data Mining?**
#
# Read the documentation for basic Markdown [here](https://www.markdownguide.org/basic-syntax).
# Turn in the text `.md` file *not* the processed `.html`.  In whatever you turn in,
# you must show the use of *ALL* the following:
#
# * headings (one level is fine),
# * bullets,
# * bold and italics
#
# Again, the content of your document needs to address the question above and it should live
# in the top level directory of your assignment submission.  This part will be graded but no
# points are awarded for your answer.
#
#
#
# ### (0%) Familiarize yourself with Github and basic git
#
# [Github (https://github.com)](https://github.com) is the _de facto_ platform for open source software in the world based
# on the very popular [git (https://git-scm.org)](https://git-scm.org) version control system. Git has a sophisticated set
# of tools for version control based on the concept of local repositories for fast commits and remote
# repositories only when collaboration and remote synchronization is necessary.  Github enhances git by providing
# tools and online hosting of public and private repositories to encourage and promote sharing and collaboration.
# Github hosts some of the world's most widely used open source software.
#
# **If you are already familiar with git and Github, then this part will be very easy!**
#
# &#167;  **CREATE A PUBLIC GITHUB REPO NAMED `"mcis6273-F20-datamining"` AND PLACE A README.MD FILE IN IT.**
# Create your first file called
# `README.md` at the top level of the repository.  You can put whatever text you like in the file
# (If you like, use something like [lorem ipsum](https://lipsum.com/)
# to generate random sentences to place in the file.).
# Please include the link to **your** Github repository that now includes the minimal `README.md`.
# You don't have to have anything elaborate in that file or the repo.
#
#
#
# ### (0%) Explore JupyterHub Linux console integrating what you learned in the prior parts of this homework
#
# The Linux console in JupyterLab is a great way to perform command-line tasks and is an essential tool
# for basic scripting that is part of a data scientist's toolkit.  Open a console in the lab environment
# and familiarize yourself with your files and basic commands using git as indicated below.
#
# 1. In a new JupyterLab command line console, run the `git clone` command to clone the new
#   repository you created in the prior part.
#   You will want to read the documentation on this
#   command (try here [https://www.git-scm.com/docs/git-clone](https://www.git-scm.com/docs/git-clone) to get a good
#   start).
# 2. Within the same console, modify your `README.md` file, check it in and push it back to your repository, using
#   `git push`.  Read the [documentation about `git push`](https://git-scm.com/docs/git-push).
# 3. The commands `wget` and `curl` are useful for grabbing data and files from remote resources off the web.
#   Read the documentation on each of these commands by typing `man wget` or `man curl` in the terminal.
#   Make sure you pipe the output to a file or use the proper flags to do so.
#
# &#167;  **THERE IS NOTHING TO TURN IN FOR THIS PART.**
#
#
#
# ### (40%) Listen to the O'Reilly Data Show Podcast from July 18, 2019: Acquiring and sharing high-quality data with Roger Chen
#
# Data is one of the most important components of modern business and, of course, data manifests
# in many forms, and involves producers, consumers and value-added uses of data.  Recently,
# data has become the source of contention, especially as large companies continue to take control
# of individual's data and use it in ways that do no benefit, and in some cases
# are used in ways that were neither approved or known by, the the individual directly.
#
# There are a number of interesting movements in data protection, such as the European Union's GDPR
# (General Data Protection Regulation - [https://eugdpr.org](https://eugdpr.org)) that are trying to
# hold companies account for how individual's data are collected, accessed, shared, distributed and protected.
# Some argue these efforts don't go far enough to acknowledge the true value of data and don't provide
# access to controlling data in ways that would benefit the individual directly, should they
# want to have it knowingly used and offered as a product to companies.  In scenarios like these,
# the individual is then brought into the data transaction as a producer, and companies act as
# consumers that add value to other consumers, etc.
#
# Blockchain has been proposed as a technology that might provide a way to coordinate the
# development of decentralized and distributed data "ledgers" that may provide a more complete
# platform to share data, trace it's lineage, but also validate and facilitate data transactions
# between consumers and producers.
#
# In this podcast, [Ben Lorica](https://www.oreilly.com/talent/4e7ad-ben-lorica) interviews Roger
# Chen, CEO of Computable Labs, about his recent paper _"Fair value and decentralized governance of data"_.
# Though it is not necessary, you are encouraged to read the very accessible white paper Chen, et al
# published in June which forms the basis of parts of the conversation in the podcast
# (that paper is on Github here: [https://git.io/fjpTv]([https://git.io/fjpTv]())).
#
# Please listen to the Podcast released July 18, 2019 _"Acquiring and Sharing High-Quality Data"_ on
# the O'Reilly Data Show.  You can listen to it from one of the two links below:
#
# * [https://soundcloud.com/oreilly-radar/acquiring-and-sharing-high-quality-data](https://soundcloud.com/oreilly-radar/acquiring-and-sharing-high-quality-data)
#
# * [https://www.oreilly.com/ideas/acquiring-and-sharing-high-quality-data](https://www.oreilly.com/ideas/acquiring-and-sharing-high-quality-data)
#
# &#167;  **PLEASE ANSWER THE FOLLOWING 8 QUESTIONS AFTER LISTENING TO THE PODCAST:**
#
# 1. Early in the interview Roger was asked what problems were being approached (and attempted to being solved) through the white paper "Fair value and decentralized governance of data". What two core areas of data did Roger say he and his Computable Labs company trying to solve?
#
# 2. In the Enterprise use case, what did Roger say about how to determine who owns data?
#
# 3. What did Roger say are some of the problems with company's centralizing data as it stands right now?
#
# 4. Roger describes a simple example of the basic workflow of how data is served by his technology
# through the use of decentralized "protocol contracts" and what he calls the "Datatrust" storage.
# In your own words, describe how this process works.
#
# 5. Roger suggests a data marketplace model of service providers so that there is decentralized
# universal access to data, and mentions how "next generation crowd-source models"  will propel
#  the fair market value of data. What property did he say
# this fair market value would be based on to derive this value?
#
# 6. Roger is bullish on Data privacy and encryption technologies and how we might have a future where
# data on the Internet is open, fully encrypted and secure "in the open".  What two companies did
# he think would be one's to watch in this space?
#
# 7. What is a "synthetic" dataset (as described in the interview), and what problems did Ben challenge
# Roger on with a market where these datasets might exist?
#
# 8. Which Blockchain network will the project be available for testing?
#
#
#
# ### (60%) Explore Python for data munging and analysis, with an introduction to CSV and Pandas
#
#
# Python's strengths shine when tasked with data munging and analysis.  As we will learn throughout
# the course, there are a number of excellent data sources for open data of all kinds now
# available for the public.  These open data sources are heralding the new era of transparency
# from all levels from small municipal data to big government data, from transportation, to science,
# to education.
#
# To warm up to such datasets, we will be working with an interesting dataset of enrollment data
# from the University of Hawaii system.  This data is in a CSV (comma-separated-values) format
# and like many datasets out there, requires a bit of restructuring to derive value from it.
#
# CSV is a format that you will often see as a _de facto_ format for data that is relatively
# flat or well adapted to tabular analyses.  You will also see JSON as the standard format for
# developing structured data, but luckily we will be able to use Python tools (specifically Pandas)
# to work with these types of data easily.
#
# The data we are going to use can be accessed via APIs but we will not need to access it that
# way for this part of the exercise.  Instead, we will be able to load it directly.
#
# In this part of the assignment, we will make use of Python libraries to pull the data from the
# endpoint and use [Pandas](https://pandas.pydata.org) to plot the data.  The raw CSV data is
# readily imported into Pandas from the following URL:
#
#
# * [Hawaii.gov Open Data for University of Hawaii enrollment](https://opendata.hawaii.gov/dataset/university-of-hawaii-enrollment-by-zip/resource/18857159-3524-4abc-8cb1-107b4207e734)
#
# Please take a look at the page, on it you will notice a link to the raw CSV file:
#
# * [https://opendata.hawaii.gov/dataset/01dc1eab-6627-4843-87c3-f78b922fca4e/resource/18857159-3524-4abc-8cb1-107b4207e734/download/enrollment-by-zipcode.csv](https://opendata.hawaii.gov/dataset/01dc1eab-6627-4843-87c3-f78b922fca4e/resource/18857159-3524-4abc-8cb1-107b4207e734/download/enrollment-by-zipcode.csv)
#
# We are going to explore this dataset to learn a bit more about the enrollment characteristics of the University
# system over the past half decade or so.
#
# &#167;  **WRITE THE CODE IN YOUR NOTEBOOK TO LOAD AND RESHAPE THE COMPLETE CSV ENROLLMENT DATASET**:
#
# You will need to perform the following steps:
#
# 1. **use [`pandas.read_csv()`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html) method to load the dataset** into a Pandas DataFrame;
# 2. **clean the data so that all zip codes are normalized to just the ZIP5 format (e.g. 80246) not the ZIP5 + 4
# (e.g. 80248-1234) format**; some of the data do not adhere the ZIP5 at all, so just remove them completely;
# 3. **create a column `YEAR` in your dataset for the year** you will notice that the original column
#    `SEMESTER` is the form `Fall 20nn`.  You will need to split this and just keep the year;
# 4. **drop the `HAWAIIAN_LEGACY` column** -- we will not need it;
# 4. **eliminate any rows of data with `NaN` data in it**;
# 5. **store the entire dataset back into a new CSV** file called `hawaii_enrollments.csv`.
#
# **HINTS:** _Here are some a code hints you might like to study and use to craft a solution:_
#
# * study the [`pandas.Series.str`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.html?highlight=str#pandas.Series.str) functionality to understand how you might turn the zip codes into ZIP5 format.
# * study the [`pandas.DataFrame.dropna()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html?highlight=dropna#pandas.DataFrame.dropna) method to drop rows with `NaN` values.
# * study the [`pandas.DataFrame.drop(columns='xxx')`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html?highlight=drop#pandas.DataFrame.drop) to understand how
#   to remove columns from your DataFrame.
#
#
# &#167;  **USE PANDAS TO LOAD THE CSV DATA TO A DATAFRAME AND ANSWER THE FOLLOWING QUESTIONS:**
#
# 1. How many total students were cumulatively enrolled in total from 2014 to 2019?
# 2. Which campus had the most cumulatively enrolled students from 2014-2019 (and what is that value)?
# 3. Which campus has the least?
# 4. Which Hawaii zip code does the largest number of students come from (across all campuses)?
# 5. Which Hawaii zip code does the largest number of students come from for the Manoa flagship campus?
#
# To answer these questions, you'll need to dive further into Pandas, which is
# the standard tool in the Python data science stack for loading, manipulating,
# transforming, analyzing and preparing data as input to other tools such as
# [Numpy (http://www.numpy.org/)](http://www.numpy.org/),
# [SciKitLearn (http://scikit-learn.org/stable/index.html)](http://scikit-learn.org/stable/index.html),
# [NLTK (http://www.nltk.org/)](http://www.nltk.org/) and others.
#
# For this assignment, you will only need to learn how to load and select data using Pandas.
#
# * **LOADING DATA**
# The core data structure in Pandas is the `DataFrame`.  You will need to visit
# the Pandas documentation [(https://pandas.pydata.org/pandas-docs/stable/reference/)](https://pandas.pydata.org/pandas-docs/stable/reference/)
# to learn more about the library, but to help you along with a hint, read the
# documentation on the [`pandas.read_csv()`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html) method.
#
# * **SELECTING DATA**
# The [tutorial here on indexing and selecting](http://pandas.pydata.org/pandas-docs/stable/indexing.html)
# should be of great use in understanding how to index and select subsets of
# the data to answer the questions.
#
# * **GROUPING DATA** You may use [`DataFrame.value_counts()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.value_counts.html?highlight=value_counts#pandas.DataFrame.value_counts) or [`DataFrame.groupby()`](https://pandas.pydata.org/pandas-docs/stable/reference/groupby.html) to group
# the data you need for these questons.
#
# **CODE HINTS**
#
# Here is example code that should give you clues about the structure
# of your code for this part.
#
# ```python
#   import pandas as pd
#
#   df = pd.read_csv('your_json_file.json')
#
#   # code for question 1 ... and so on
# ```
#
#
# &#167;  **GATHER NON-HAWAII STUDENT INFORMATION**
#
# Now that we have a decent idea of the in-state profile of students going to all
# campuses in the University of Hawaii system, let's look at the out-of-state profile.  As you may
# know, many universities have large out-of-state student populations and some
# universities rely on out-of-state tuition as an important source of operating revenue for
# the university.  Let's explore what the out of state profile looks like at the flagship Manoa campus.
#
# For this part you will do well to use an API to assign a state code to each
# zip code.  What you will be expected to do is the following steps:
#
# 1. aggregate all zip codes from 2014-2019 for the Manoa campus,
# 1. assign a state code to the zip codes,
# 1. get an aggregate count of all enrollment numbers by state from 2014-2019.
#
# In order to assign state codes, you may use a number of techniques.
#
# **OPTION ONE (SLOWEST): USE AN API**
#
# One option is to use external APIs, such the one
# free API [zipcodeapi.com](https://www.zipcodeapi.com) which allows you to query
# by zipcode and return a JSON payload which contains information such
# as city, state, etc.  To help you along, you will can just adapt the code below:
#
# ```python
#   import requests
#   import time
#
#   # 967xx-969xx are Hawaii zip codes
#   if len(z) == 5 and z[:3] not in ['969', '968', '967']:
#       url = f"https://www.zipcodeapi.com/rest/
#               gUA29rOpQB4A2Nt6ZxL69KDokVOKy2xfoR9KZR5iIOTi2rj6GoCaaJtQWxNkcW2q/info.json/{z}/degrees"
#       r = requests.get(url)
#
#       if r.status_code == 200:
#           payload = r.json()
#           # do work  with  your JSON payload to obtain the state code
#       else:
#           pass
#           # print(r.status_code)
#       time.sleep(2)  # NOTE: the delay is to avoid rate limiting!
# ```
#
# Just remember the JSON payload looks like this (verify for yourself):
#
# ```json
#     {
#       "zip_code":"40504",
#       "lat":38.042391,
#       "lng":-84.543931,
#       "city":"Lexington",
#       "state":"KY",
#       "timezone":{
#           "timezone_identifier":"America\/New_York",
#           "timezone_abbr":"EDT",
#           "utc_offset_sec":-14400,
#           "is_dst":"T"
#       },
#       "acceptable_city_names":[],
#       "area_codes":[859]
#     }
# ```
# **OPTION TWO (EASIEST): USE A GEONAMES.ORG PYTHON LIBRARY**
#
# Lucky for us, there is yet another service called [Geonames.org](https://geonames.org) which
# not only has an API, but others have created Python libraries on top of that API.  Geonames,
# much like zipcodeapi.com, provides mappings from zip to city, state and other information.  It
# also provides much, much more if you ever need to obtain latitude or longitude data for
# your programming and data needs.  One such library written for Python is
# the open source [`pgeocode`](https://github.com/symerio/pgeocode), and you may use this library.
#
# In order to install it, open a terminal in your JupyterLab session
# on the Hub and type:
#
# ```bash
#   pip install pgeocode
# ```
#
# Full documentation for the library is here [https://pgeocode.readthedocs.io/en/latest/overview.html](https://pgeocode.readthedocs.io/en/latest/overview.html),
# but your solution might look something like this:
#
# ```python
#   import pgeocode
#
#   nomi = pgeocode.Nominatim('us')
#   nomi.query_postal_code("13804")['state_code']
# ```
# Which would return:
#
# ```bash
#   'ny'
# ```
#
# With this you could craft a solution quite easily to map the zipcode to the state
# and then build up what is being asked.
#
# **OPTION THREE (EASIER): USE A STATIC FILE FROM GEONAMES.ORG**
#
# Another last option would be to load the full Geonames.org zipcode data file into
# a DataFrame and query it to obtain the data you're needing.
#
# * the Geonames file is here: [https://download.geonames.org/export/zip/US.zip](https://download.geonames.org/export/zip/US.zip)
#
# You can download it from the terminal with (the capitalization matters):
#
# ```bash
#   wget https://download.geonames.org/export/zip/US.zip
#   unzip US.zip
# ```
#
# Or you can create a Jupyter cell with the magic command:
#
# ```
#   !wget https://download.geonames.org/export/zip/US.zip
#   !unzip US.zip
# ```
#
# Whichever way you choose, you will then have a file `US.txt`.  Load it into a DataFrame with:
#
# ```python
#   import pandas as pd
#   df_zip = pandas.read_csv("US.txt", header=None, sep='\t')
# ```
#
# Then you will be able to get the state with something like this:
#
# ```python
#   df_zip[ df_zip[1]==57641 ][4].item()  # the zero-based index 1st item is zip, 4th the state code
# ```
#
# Which will return:
#
# ```bash
#   'SD'
# ```
#
# No matter the method you choose, your solution will include a DataFrame that will simply be the aggregation
# of the sum of zip codes or something like this (HINT: `value_counts()` will be useful again):
#
# |    |   ENROLLMENT |
# |:---|-------------:|
# | ... |         ... |
# | AR |          911 |
# | ND |          110 |
# | WV |          610 |
# | DC |           86 |
# | DE |           26 |
# | ... |         ... |
#
#
# &#167;  **Export that table to a CSV using `DataFrame.to_csv('zip_code_summary.csv')`.**
#
# Make sure the file name is as specified, so I can verify the contents.
#
#
# &#167;  **Plot the top 15 (non-Hawaii) states by enrollment:**
#
# Using the [`Series.plot(kind='bar'`)](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.plot.html?highlight=plot#pandas.Series.plot), plot a simple bar plot of the top 15 states
# using the solution from the previous part.  This is relatively easy and is one line of
# code.

# %% [markdown]
# <h1>§ PLEASE ANSWER THE FOLLOWING 8 QUESTIONS AFTER LISTENING TO THE PODCAST:</h1>

# %% [markdown]
# 1. Early in the interview Roger was asked what problems were being approached (and attempted to being solved) through the white paper "Fair value and decentralized governance of data". What two core areas of data did Roger say he and his Computable Labs company trying to solve?

# %% [markdown]
# Ans:
# Bailis is also an assistant professor of computer science at Stanford University ... I spoke with Roger Chen, co-founder and CEO of Computable Labs, a startup ... new white paper, "Fair value and decentralized governance of data. ... for solving RL problems, I expect many of the first applications to be in industrial automation.

# %% [markdown]
# 2. In the Enterprise use case, what did Roger say about how to determine who owns data?

# %% [markdown]
# 3. What did Roger say are some of the problems with company's centralizing data as it stands right now?

# %% [markdown]
# #############################################################################################

# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\sh\\Desktop\\USA\\Rajanala\\DataMining\\mcis6273_f20_datamining-master\\mcis6273_f20_datamining-master\\homework\\hw0'

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 68FC-B994
#
#  Directory of C:\Users\sh\Desktop\USA\Rajanala\DataMining\mcis6273_f20_datamining-master\mcis6273_f20_datamining-master\homework\hw0
#
# 09/02/2020  12:50 AM    <DIR>          .
# 09/02/2020  12:50 AM    <DIR>          ..
# 08/31/2020  08:05 AM    <DIR>          .ipynb_checkpoints
# 09/02/2020  12:50 AM           194,951 123.ipynb
# 09/01/2020  10:08 PM               245 degrees.json
# 08/30/2020  05:08 AM         5,418,862 enrollment-by-zipcode.csv
# 09/02/2020  01:46 AM           833,219 hawaii_enrollments.csv
# 08/28/2020  02:24 PM            23,303 hw0.docx
# 08/28/2020  02:24 PM            33,871 hw0.html
# 09/02/2020  12:30 AM            55,775 hw0.ipynb
# 08/28/2020  02:24 PM            22,919 hw0.md
# 08/28/2020  02:24 PM           233,616 hw0.pdf
# 08/28/2020  02:24 PM               387 README.md
# 09/01/2020  03:19 AM         2,663,242 US.txt
# 09/02/2020  12:48 AM             1,010 zip_code_summary.csv
#               12 File(s)      9,481,400 bytes
#                3 Dir(s)  234,703,433,728 bytes free

# %%
data = pd.read_csv("enrollment-by-zipcode.csv")

# %%
data[(data.IRO_INSTITUTION_DESCL.str.contains('Manoa'))]
# Out:
#         SEMESTER SPRADDR_ZIP_PR           IRO_INSTITUTION_DESCL  \
# 7      Fall 2012          96789  University of Hawai`i at Manoa
# 8      Fall 2012          96712  University of Hawai`i at Manoa
# 11     Fall 2012          96813  University of Hawai`i at Manoa
# 12     Fall 2012          96822  University of Hawai`i at Manoa
# 13     Fall 2012          96816  University of Hawai`i at Manoa
# ...          ...            ...                             ...
# 87785  Fall 2019          84047  University of Hawai`i at Manoa
# 87786  Fall 2019     94531-9344  University of Hawai`i at Manoa
# 87788  Fall 2019          43402  University of Hawai`i at Manoa
# 87796  Fall 2019     96822-4243  University of Hawai`i at Manoa
# 87797  Fall 2019          57103  University of Hawai`i at Manoa
#
#       HAWAIIAN_LEGACY  ENROLLMENT
# 7                 NaN          80
# 8                 NaN          37
# 11                NaN          26
# 12                NaN          87
# 13                NaN         184
# ...               ...         ...
# 87785        HAWAIIAN           1
# 87786             NaN           1
# 87788             NaN           1
# 87796             NaN           1
# 87797             NaN           1
#
# [36594 rows x 5 columns]

# %%
data.head()
# Out:
#     SEMESTER SPRADDR_ZIP_PR         IRO_INSTITUTION_DESCL HAWAIIAN_LEGACY  \
# 0  Fall 2012          96766      Kaua`i Community College        HAWAIIAN
# 1  Fall 2012          96814  Kapi`olani Community College             NaN
# 2  Fall 2012          96792     Leeward Community College        HAWAIIAN
# 3  Fall 2012          96822    Honolulu Community College             NaN
# 4  Fall 2012          96821  Kapi`olani Community College             NaN
#
#    ENROLLMENT
# 0          73
# 1          19
# 2         504
# 3          12
# 4          43

# %%
data
# Out:
#         SEMESTER SPRADDR_ZIP_PR           IRO_INSTITUTION_DESCL  \
# 0      Fall 2012          96766        Kaua`i Community College
# 1      Fall 2012          96814    Kapi`olani Community College
# 2      Fall 2012          96792       Leeward Community College
# 3      Fall 2012          96822      Honolulu Community College
# 4      Fall 2012          96821    Kapi`olani Community College
# ...          ...            ...                             ...
# 87793  Fall 2019     96822-5703      Honolulu Community College
# 87794  Fall 2019     96817-1733      Honolulu Community College
# 87795  Fall 2019     96744-4205      Windward Community College
# 87796  Fall 2019     96822-4243  University of Hawai`i at Manoa
# 87797  Fall 2019          57103  University of Hawai`i at Manoa
#
#       HAWAIIAN_LEGACY  ENROLLMENT
# 0            HAWAIIAN          73
# 1                 NaN          19
# 2            HAWAIIAN         504
# 3                 NaN          12
# 4                 NaN          43
# ...               ...         ...
# 87793             NaN           1
# 87794             NaN           1
# 87795             NaN           1
# 87796             NaN           1
# 87797             NaN           1
#
# [87798 rows x 5 columns]

# %%
data['SPRADDR_ZIP_PR'].unique()
# Out:
# array(['96766', '96814', '96792', ..., '96826-2533', '96817-1733',
#        '96744-4205'], dtype=object)

# %%
data.head(100)
# Out:
#      SEMESTER SPRADDR_ZIP_PR           IRO_INSTITUTION_DESCL HAWAIIAN_LEGACY  \
# 0   Fall 2012          96766        Kaua`i Community College        HAWAIIAN
# 1   Fall 2012          96814    Kapi`olani Community College             NaN
# 2   Fall 2012          96792       Leeward Community College        HAWAIIAN
# 3   Fall 2012          96822      Honolulu Community College             NaN
# 4   Fall 2012          96821    Kapi`olani Community College             NaN
# ..        ...            ...                             ...             ...
# 95  Fall 2012            NaN  University of Hawai`i at Manoa             NaN
# 96  Fall 2012          93455   University of Hawai`i at Hilo        HAWAIIAN
# 97  Fall 2012            NaN   University of Hawai`i at Hilo             NaN
# 98  Fall 2012          96766  University of Hawai`i at Manoa             NaN
# 99  Fall 2012          96795      Windward Community College             NaN
#
#     ENROLLMENT
# 0           73
# 1           19
# 2          504
# 3           12
# 4           43
# ..         ...
# 95         162
# 96           1
# 97          12
# 98          19
# 99           7
#
# [100 rows x 5 columns]

# %%
na_values = ['', 'N/A', '0']

# %%
requests = pd.read_csv('enrollment-by-zipcode.csv', na_values=na_values, dtype={'SPRADDR_ZIP_PR': str})

# %%
requests['SPRADDR_ZIP_PR'].unique()
# Out:
# array(['96766', '96814', '96792', ..., '96826-2533', '96817-1733',
#        '96744-4205'], dtype=object)

# %%
requests["SPRADDR_ZIP_PR"].describe()
# Out:
# count     86663
# unique    16253
# top       96797
# freq       1001
# Name: SPRADDR_ZIP_PR, dtype: object

# %%
rows_with_dashes = requests['SPRADDR_ZIP_PR'].str.contains('-').fillna(False)

# %%
len(requests[rows_with_dashes])
# Out:
# 10265

# %%
requests[rows_with_dashes]
# Out:
#         SEMESTER SPRADDR_ZIP_PR           IRO_INSTITUTION_DESCL  \
# 345    Fall 2012     96797-1510      Honolulu Community College
# 485    Fall 2012     95020-7514  University of Hawai`i at Manoa
# 545    Fall 2012       965-0867  University of Hawai`i at Manoa
# 552    Fall 2012     33177-2009  University of Hawai`i at Manoa
# 553    Fall 2012     96837-0814  University of Hawai`i at Manoa
# ...          ...            ...                             ...
# 87792  Fall 2019     96826-2533      Honolulu Community College
# 87793  Fall 2019     96822-5703      Honolulu Community College
# 87794  Fall 2019     96817-1733      Honolulu Community College
# 87795  Fall 2019     96744-4205      Windward Community College
# 87796  Fall 2019     96822-4243  University of Hawai`i at Manoa
#
#       HAWAIIAN_LEGACY  ENROLLMENT
# 345               NaN           1
# 485               NaN           1
# 545               NaN           1
# 552               NaN           1
# 553               NaN           1
# ...               ...         ...
# 87792             NaN           1
# 87793             NaN           1
# 87794             NaN           1
# 87795             NaN           1
# 87796             NaN           1
#
# [10265 rows x 5 columns]

# %%
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
requests['SPRADDR_ZIP_PR'][rows_with_dashes] = np.nan

# %%
requests['SPRADDR_ZIP_PR'][rows_with_dashes]
# Out:
# 345      NaN
# 485      NaN
# 545      NaN
# 552      NaN
# 553      NaN
#         ...
# 87792    NaN
# 87793    NaN
# 87794    NaN
# 87795    NaN
# 87796    NaN
# Name: SPRADDR_ZIP_PR, Length: 10265, dtype: object

# %%
requests['SPRADDR_ZIP_PR']
# Out:
# 0        96766
# 1        96814
# 2        96792
# 3        96822
# 4        96821
#          ...
# 87793      NaN
# 87794      NaN
# 87795      NaN
# 87796      NaN
# 87797    57103
# Name: SPRADDR_ZIP_PR, Length: 87798, dtype: object

# %%
na_values = ['NO CLUE', 'N/A', '0']
requests = pd.read_csv('enrollment-by-zipcode.csv', 
                       na_values=na_values, 
                       dtype={'SPRADDR_ZIP_PR': str})

def fix_zip_codes(zips):
    # Truncate everything to length 5 
    zips = zips.str.slice(0, 5)
    
    # Set 00000 zip codes to nan
    zero_zips = zips == '00000'
    zips[zero_zips] = np.nan
    
    return zips
    
requests['SPRADDR_ZIP_PR'] = fix_zip_codes(requests['SPRADDR_ZIP_PR'])
requests['SPRADDR_ZIP_PR'].unique()
# Out:
# array(['96766', '96814', '96792', ..., '56721', '55103', '70124'],
#       dtype=object)

# %%
# remove all the rows that contain a missing value
requests.dropna()
# Out:
#         SEMESTER SPRADDR_ZIP_PR               IRO_INSTITUTION_DESCL  \
# 0      Fall 2012          96766            Kaua`i Community College
# 2      Fall 2012          96792           Leeward Community College
# 9      Fall 2012          96744          Windward Community College
# 30     Fall 2012          96822      University of Hawai`i at Manoa
# 35     Fall 2012          96790      University of Hawai`i at Manoa
# ...          ...            ...                                 ...
# 87779  Fall 2019          96706  University of Hawai`i - West O`ahu
# 87784  Fall 2019          96789           Leeward Community College
# 87785  Fall 2019          84047      University of Hawai`i at Manoa
# 87789  Fall 2019          96740           Hawai`i Community College
# 87791  Fall 2019          96822          Honolulu Community College
#
#       HAWAIIAN_LEGACY  ENROLLMENT
# 0            HAWAIIAN          73
# 2            HAWAIIAN         504
# 9            HAWAIIAN         463
# 30           HAWAIIAN         101
# 35           HAWAIIAN          20
# ...               ...         ...
# 87779        HAWAIIAN           1
# 87784        HAWAIIAN           1
# 87785        HAWAIIAN           1
# 87789        HAWAIIAN           1
# 87791        HAWAIIAN           1
#
# [14040 rows x 5 columns]

# %%
#requests['YEAR']=2020
#requests
# dropping null value columns to avoid errors 
requests.dropna(inplace = True) 
  
# new data frame with split value columns 
new = requests["SEMESTER"].str.split(" ", n = 1, expand = True) 
  
# making separate first name column from new data frame 
#requests["First Name"]= new[0] 
  
# making separate last name column from new data frame 
requests["YEAR"]= new[1] 
  
# Dropping old Name columns 
#requests.drop(columns =["Name"], inplace = True)

# %%
new
# Out:
#           0     1
# 0      Fall  2012
# 2      Fall  2012
# 9      Fall  2012
# 30     Fall  2012
# 35     Fall  2012
# ...     ...   ...
# 87779  Fall  2019
# 87784  Fall  2019
# 87785  Fall  2019
# 87789  Fall  2019
# 87791  Fall  2019
#
# [14040 rows x 2 columns]

# %%
requests
# Out:
#         SEMESTER SPRADDR_ZIP_PR               IRO_INSTITUTION_DESCL  \
# 0      Fall 2012          96766            Kaua`i Community College
# 2      Fall 2012          96792           Leeward Community College
# 9      Fall 2012          96744          Windward Community College
# 30     Fall 2012          96822      University of Hawai`i at Manoa
# 35     Fall 2012          96790      University of Hawai`i at Manoa
# ...          ...            ...                                 ...
# 87779  Fall 2019          96706  University of Hawai`i - West O`ahu
# 87784  Fall 2019          96789           Leeward Community College
# 87785  Fall 2019          84047      University of Hawai`i at Manoa
# 87789  Fall 2019          96740           Hawai`i Community College
# 87791  Fall 2019          96822          Honolulu Community College
#
#       HAWAIIAN_LEGACY  ENROLLMENT  YEAR
# 0            HAWAIIAN          73  2012
# 2            HAWAIIAN         504  2012
# 9            HAWAIIAN         463  2012
# 30           HAWAIIAN         101  2012
# 35           HAWAIIAN          20  2012
# ...               ...         ...   ...
# 87779        HAWAIIAN           1  2019
# 87784        HAWAIIAN           1  2019
# 87785        HAWAIIAN           1  2019
# 87789        HAWAIIAN           1  2019
# 87791        HAWAIIAN           1  2019
#
# [14040 rows x 6 columns]

# %%
requests = requests.drop(columns='HAWAIIAN_LEGACY')

# %%
requests.to_csv('hawaii_enrollments.csv')

# %%
requests.head(1000)
# Out:
#        SEMESTER SPRADDR_ZIP_PR               IRO_INSTITUTION_DESCL  \
# 0     Fall 2012          96766            Kaua`i Community College
# 2     Fall 2012          96792           Leeward Community College
# 9     Fall 2012          96744          Windward Community College
# 30    Fall 2012          96822      University of Hawai`i at Manoa
# 35    Fall 2012          96790      University of Hawai`i at Manoa
# ...         ...            ...                                 ...
# 6459  Fall 2017          96822      University of Hawai`i at Manoa
# 6464  Fall 2017          96766           Hawai`i Community College
# 6465  Fall 2017          96766            Kaua`i Community College
# 6467  Fall 2017          96712  University of Hawai`i - West O`ahu
# 6468  Fall 2017          96792           Hawai`i Community College
#
#       ENROLLMENT  YEAR
# 0             73  2012
# 2            504  2012
# 9            463  2012
# 30           101  2012
# 35            20  2012
# ...          ...   ...
# 6459          82  2017
# 6464          11  2017
# 6465         106  2017
# 6467           4  2017
# 6468           6  2017
#
# [1000 rows x 5 columns]

# %% [markdown]
# <h1>§ USE PANDAS TO LOAD THE CSV DATA TO A DATAFRAME AND ANSWER THE FOLLOWING QUESTIONS:</h1>

# %% [markdown]
# 1. How many total students were cumulatively enrolled in total from 2014 to 2019?

# %%
# total rows
len(requests)
# Out:
# 14040

# %%
# making a bool series 
enrolled_students_from2014_to_2019 = requests["YEAR"].between('2014', '2019', inclusive = True) 
  
# returning dataframe with salary between above values 
requests[enrolled_students_from2014_to_2019]
# Out:
#         SEMESTER SPRADDR_ZIP_PR               IRO_INSTITUTION_DESCL  \
# 2668   Fall 2014          96746            Kaua`i Community College
# 2683   Fall 2014          96706  University of Hawai`i - West O`ahu
# 2687   Fall 2014          96734      University of Hawai`i at Manoa
# 2688   Fall 2014          96709           Leeward Community College
# 2700   Fall 2014          96789      University of Hawai`i at Manoa
# ...          ...            ...                                 ...
# 87779  Fall 2019          96706  University of Hawai`i - West O`ahu
# 87784  Fall 2019          96789           Leeward Community College
# 87785  Fall 2019          84047      University of Hawai`i at Manoa
# 87789  Fall 2019          96740           Hawai`i Community College
# 87791  Fall 2019          96822          Honolulu Community College
#
#        ENROLLMENT  YEAR
# 2668          101  2014
# 2683           59  2014
# 2687          127  2014
# 2688            4  2014
# 2700          126  2014
# ...           ...   ...
# 87779           1  2019
# 87784           1  2019
# 87785           1  2019
# 87789           1  2019
# 87791           1  2019
#
# [10893 rows x 5 columns]

# %%
len(requests[enrolled_students_from2014_to_2019] )
# Out:
# 10893

# %% [markdown]
# 2. Which campus had the most cumulatively enrolled students from 2014-2019 (and what is that value)?

# %%
requests
# Out:
#         SEMESTER SPRADDR_ZIP_PR               IRO_INSTITUTION_DESCL  \
# 0      Fall 2012          96766            Kaua`i Community College
# 2      Fall 2012          96792           Leeward Community College
# 9      Fall 2012          96744          Windward Community College
# 30     Fall 2012          96822      University of Hawai`i at Manoa
# 35     Fall 2012          96790      University of Hawai`i at Manoa
# ...          ...            ...                                 ...
# 87779  Fall 2019          96706  University of Hawai`i - West O`ahu
# 87784  Fall 2019          96789           Leeward Community College
# 87785  Fall 2019          84047      University of Hawai`i at Manoa
# 87789  Fall 2019          96740           Hawai`i Community College
# 87791  Fall 2019          96822          Honolulu Community College
#
#        ENROLLMENT  YEAR
# 0              73  2012
# 2             504  2012
# 9             463  2012
# 30            101  2012
# 35             20  2012
# ...           ...   ...
# 87779           1  2019
# 87784           1  2019
# 87785           1  2019
# 87789           1  2019
# 87791           1  2019
#
# [14040 rows x 5 columns]

# %%
requests.dtypes
# Out:
# SEMESTER                 object
# SPRADDR_ZIP_PR           object
# IRO_INSTITUTION_DESCL    object
# ENROLLMENT                int64
# YEAR                     object
# dtype: object

# %%
requests['YEAR'] = requests['YEAR'].astype(int)

# %%
requests.dtypes
# Out:
# SEMESTER                 object
# SPRADDR_ZIP_PR           object
# IRO_INSTITUTION_DESCL    object
# ENROLLMENT                int64
# YEAR                      int32
# dtype: object

# %%
len(requests)
# Out:
# 14040

# %%
most_recentname=requests.loc[(requests.YEAR >= 2014 ) & (requests.YEAR <= 2019),:]

# %%
most_recentname['YEAR'].max()
# Out:
# 2019

# %%
len(requests['IRO_INSTITUTION_DESCL'])
# Out:
# 14040

# %%
len(most_recentname['IRO_INSTITUTION_DESCL'])
# Out:
# 10893

# %%
most_recentname['IRO_INSTITUTION_DESCL'].max()
# Out:
# 'Windward Community College'

# %%
most_recentname['IRO_INSTITUTION_DESCL'].value_counts()[0]
# Out:
# 2725

# %%
most_recentname['IRO_INSTITUTION_DESCL'].value_counts()
# Out:
# University of Hawai`i at Manoa        2725
# Leeward Community College             1247
# Kapi`olani Community College          1219
# Hawai`i Community College              972
# Windward Community College             946
# Honolulu Community College             937
# University of Hawai`i at Hilo          886
# University of Hawai`i Maui College     870
# University of Hawai`i - West O`ahu     673
# Kaua`i Community College               418
# Name: IRO_INSTITUTION_DESCL, dtype: int64

# %% [markdown]
# 3. Which campus has the least?

# %%
requests['IRO_INSTITUTION_DESCL'].value_counts()
# Out:
# University of Hawai`i at Manoa        3599
# Kapi`olani Community College          1611
# Leeward Community College             1540
# Hawai`i Community College             1260
# Honolulu Community College            1207
# University of Hawai`i at Hilo         1189
# Windward Community College            1150
# University of Hawai`i Maui College    1092
# University of Hawai`i - West O`ahu     850
# Kaua`i Community College               542
# Name: IRO_INSTITUTION_DESCL, dtype: int64

# %%
requests['IRO_INSTITUTION_DESCL'].value_counts()
# Out:
# University of Hawai`i at Manoa        3599
# Kapi`olani Community College          1611
# Leeward Community College             1540
# Hawai`i Community College             1260
# Honolulu Community College            1207
# University of Hawai`i at Hilo         1189
# Windward Community College            1150
# University of Hawai`i Maui College    1092
# University of Hawai`i - West O`ahu     850
# Kaua`i Community College               542
# Name: IRO_INSTITUTION_DESCL, dtype: int64

# %%
requests['IRO_INSTITUTION_DESCL'].value_counts()[9]
# Out:
# 542

# %% [markdown]
# 4. Which Hawaii zip code does the largest number of students come from (across all campuses)?

# %%
#len(requests['SPRADDR_ZIP_PR'])
requests['SPRADDR_ZIP_PR'].value_counts()
dict_results= dict(requests['SPRADDR_ZIP_PR'].value_counts())
i=0
for k, v in dict_results.items():
    if(i==1):
        break
    else:
        i=i+1
    #print(k, v)
    print("zip code={}, Total Count= {}".format(k, v))
# Out:
# zip code=96744, Total Count= 488

# %%
len(requests['SPRADDR_ZIP_PR'].value_counts())
# Out:
# 1019

# %%
requests['SPRADDR_ZIP_PR'].value_counts().dtypes
# Out:
# dtype('int64')

# %%
requests['SPRADDR_ZIP_PR'].value_counts()[0]
# Out:
# 488

# %% [markdown]
# ==================================================================

# %%
requests
# Out:
#         SEMESTER SPRADDR_ZIP_PR               IRO_INSTITUTION_DESCL  \
# 0      Fall 2012          96766            Kaua`i Community College
# 2      Fall 2012          96792           Leeward Community College
# 9      Fall 2012          96744          Windward Community College
# 30     Fall 2012          96822      University of Hawai`i at Manoa
# 35     Fall 2012          96790      University of Hawai`i at Manoa
# ...          ...            ...                                 ...
# 87779  Fall 2019          96706  University of Hawai`i - West O`ahu
# 87784  Fall 2019          96789           Leeward Community College
# 87785  Fall 2019          84047      University of Hawai`i at Manoa
# 87789  Fall 2019          96740           Hawai`i Community College
# 87791  Fall 2019          96822          Honolulu Community College
#
#        ENROLLMENT  YEAR
# 0              73  2012
# 2             504  2012
# 9             463  2012
# 30            101  2012
# 35             20  2012
# ...           ...   ...
# 87779           1  2019
# 87784           1  2019
# 87785           1  2019
# 87789           1  2019
# 87791           1  2019
#
# [14040 rows x 5 columns]

# %%
requests['ENROLLMENT'].max()
# Out:
# 663

# %%
# selecting rows based on condition 
rslt_df = requests[requests['ENROLLMENT'] == 663]

# %%
rslt_df
# Out:
#         SEMESTER SPRADDR_ZIP_PR      IRO_INSTITUTION_DESCL  ENROLLMENT  YEAR
# 32745  Fall 2012          96720  Hawai`i Community College         663  2012

# %% [markdown]
# OR

# %%
# selecting rows based on condition 
rslt_df1 = requests.loc[requests['ENROLLMENT'] == 663] 
  
print('\nResult dataframe :\n', rslt_df1)
# Out:
# Result dataframe :
#          SEMESTER SPRADDR_ZIP_PR      IRO_INSTITUTION_DESCL  ENROLLMENT  YEAR
# 32745  Fall 2012          96720  Hawai`i Community College         663  2012

# %% [markdown]
# OR

# %%
options = [663] 
  
# selecting rows based on condition 
rslt_df2 = requests[requests['ENROLLMENT'].isin(options)] 
  
print('\nResult dataframe :\n', rslt_df2)
# Out:
# Result dataframe :
#          SEMESTER SPRADDR_ZIP_PR      IRO_INSTITUTION_DESCL  ENROLLMENT  YEAR
# 32745  Fall 2012          96720  Hawai`i Community College         663  2012

# %%
dict_results=dict(rslt_df2['ENROLLMENT'])
i=0
#print('\n largest number of students of Hawaii zip code= ', r['SPRADDR_ZIP_PR'])
for k, v in dict_results.items():
    if(i==1):
        break
    else:
        i=i+1
    #print(k, v)
    print("zip code={}, largest number of students= {}".format(k, v))
# Out:
# zip code=32745, largest number of students= 663

# %% [markdown]
# 5. Which Hawaii zip code does the largest number of students come from for the Manoa flagship campus

# %%
# selecting rows based on condition 
institutions_results = requests.loc[requests['IRO_INSTITUTION_DESCL'] == "University of Hawai`i at Manoa"] 
  
print('\nInstitutions of Result dataframe :\n', institutions_results)
# Out:
# Institutions of Result dataframe :
#          SEMESTER SPRADDR_ZIP_PR           IRO_INSTITUTION_DESCL  ENROLLMENT  \
# 30     Fall 2012          96822  University of Hawai`i at Manoa         101
# 35     Fall 2012          96790  University of Hawai`i at Manoa          20
# 54     Fall 2012          96819  University of Hawai`i at Manoa           5
# 62     Fall 2012          96762  University of Hawai`i at Manoa          13
# 86     Fall 2012          92867  University of Hawai`i at Manoa           1
# ...          ...            ...                             ...         ...
# 87667  Fall 2019          95864  University of Hawai`i at Manoa           1
# 87685  Fall 2019          96790  University of Hawai`i at Manoa           1
# 87717  Fall 2019          96790  University of Hawai`i at Manoa           1
# 87775  Fall 2019          96744  University of Hawai`i at Manoa           1
# 87785  Fall 2019          84047  University of Hawai`i at Manoa           1
#
#        YEAR
# 30     2012
# 35     2012
# 54     2012
# 62     2012
# 86     2012
# ...     ...
# 87667  2019
# 87685  2019
# 87717  2019
# 87775  2019
# 87785  2019
#
# [3599 rows x 5 columns]

# %%
institutions_results['ENROLLMENT'].max()
# Out:
# 238

# %%
# selecting rows based on condition 
inst_rslt_df = institutions_results[institutions_results['ENROLLMENT'] == 238] 
inst_rslt_df
# Out:
#         SEMESTER SPRADDR_ZIP_PR           IRO_INSTITUTION_DESCL  ENROLLMENT  \
# 43683  Fall 2012          96744  University of Hawai`i at Manoa         238
#
#        YEAR
# 43683  2012

# %%
manoa_zipcode=0
max_std_manoa=0
inst_dict_results=dict(inst_rslt_df['ENROLLMENT'])
i=0
#print('\n largest number of students of Hawaii zip code= ', r['SPRADDR_ZIP_PR'])
for k, v in inst_dict_results.items():
    if(i==1):
        break
    else:
        i=i+1
    #print(k, v)
    max_std_manoa=v
    print("Largest number of students from for the Manoa flagship campus = {}".format(v))
# Out:
# Largest number of students from for the Manoa flagship campus = 238

# %%
zip_dict_results=dict(inst_rslt_df['SPRADDR_ZIP_PR'])
i=0
#print('\n largest number of students of Hawaii zip code= ', r['SPRADDR_ZIP_PR'])
for k, v in zip_dict_results.items():
    if(i==1):
        break
    else:
        i=i+1
    #print(k, v)
    manoa_zipcode=v
    print("zip code={}".format(v))
# Out:
# zip code=96744

# %%
print("Hawaii zip code = {} does the largest number of students={} come from for the Manoa flagship campus".format(manoa_zipcode,
max_std_manoa))
# Out:
# Hawaii zip code = 96744 does the largest number of students=238 come from for the Manoa flagship campus

# %%
requests.dtypes
# Out:
# SEMESTER                 object
# SPRADDR_ZIP_PR           object
# IRO_INSTITUTION_DESCL    object
# ENROLLMENT                int64
# YEAR                      int32
# dtype: object

# %% [markdown]
# ### § GATHER NON-HAWAII STUDENT INFORMATION

# %% [markdown]
# 1. aggregate all zip codes from 2014-2019 for the Manoa campus,

# %%
import pandas as pd
data = pd.read_csv("enrollment-by-zipcode.csv")

# %%
import requests
import time

z=str("40504")

# 967xx-969xx are Hawaii zip codes
if len(z) == 5 and z[:3] not in ['969', '968', '967']:
  #url = "https://www.zipcodeapi.com/rest/MSyxUswHJk1hIeeEARPhhhtse5eAPgvHJFzKS9faOnvrxZrha9pkf6XI0rwwIuxL/info.json/{z}/degrees"
  url = "https://www.zipcodeapi.com/rest/MSyxUswHJk1hIeeEARPhhhtse5eAPgvHJFzKS9faOnvrxZrha9pkf6XI0rwwIuxL/info.json/40504/degrees"
  r = requests.get(url)
  print(z[:3])
  if r.status_code == 200:
      payload = r.json()
      # do work  with  your JSON payload to obtain the state code
      print(payload)
  else:
      pass
      #print(r.status_code)
      print("[warn] GET request did not return HTTP/200 (HTTP/{} returned instead".format(r.status_code))
      print("server error:")
  time.sleep(2)  # NOTE: the delay is to avoid rate limiting!
# Out:
# 405
# {'zip_code': '40504', 'lat': 38.042391, 'lng': -84.543931, 'city': 'Lexington', 'state': 'KY', 'timezone': {'timezone_identifier': 'America/New_York', 'timezone_abbr': 'EDT', 'utc_offset_sec': -14400, 'is_dst': 'T'}, 'acceptable_city_names': [], 'area_codes': [859]}

# %%
import requests
import time

z=str("40504")

# 967xx-969xx are Hawaii zip codes
if len(z) == 5 and z[:3] not in ['969', '968', '967']:
  #url = "https://www.zipcodeapi.com/rest/MSyxUswHJk1hIeeEARPhhhtse5eAPgvHJFzKS9faOnvrxZrha9pkf6XI0rwwIuxL/info.json/{z}/degrees"
  url = "https://www.zipcodeapi.com/rest/MSyxUswHJk1hIeeEARPhhhtse5eAPgvHJFzKS9faOnvrxZrha9pkf6XI0rwwIuxL/info.json/40504/degrees"
  r = requests.get(url)
  print(z[:3])
  if r.status_code == 200:
      payload = r.json()
      # do work  with  your JSON payload to obtain the state code
      print(payload)
      #payload = {'zip_code': '40504', 'lat': 38.042391, 'lng': -84.543931, 'city': 'Lexington', 'state': 'KY', 'timezone': {'timezone_identifier': 'America/New_York', 'timezone_abbr': 'EDT', 'utc_offset_sec': -14400, 'is_dst': 'T'}, 'acceptable_city_names': [], 'area_codes': [859]}
      print("\n")
      print(payload)
      print("\n")
      #print(payload.state)
      #print('\n largest number of students of Hawaii zip code= ', r['SPRADDR_ZIP_PR'])
      for k, v in payload.items():
        if(k=="state"):
          print("Key={} value={}".format(k,v))
        else:
          pass   

  else:
      pass
      #print(r.status_code)
      print("[warn] GET request did not return HTTP/200 (HTTP/{} returned instead".format(r.status_code))
      print("server error:")
  time.sleep(2)  # NOTE: the delay is to avoid rate limiting!
# Out:
# 405
# {'zip_code': '40504', 'lat': 38.042391, 'lng': -84.543931, 'city': 'Lexington', 'state': 'KY', 'timezone': {'timezone_identifier': 'America/New_York', 'timezone_abbr': 'EDT', 'utc_offset_sec': -14400, 'is_dst': 'T'}, 'acceptable_city_names': [], 'area_codes': [859]}
#
#
# {'zip_code': '40504', 'lat': 38.042391, 'lng': -84.543931, 'city': 'Lexington', 'state': 'KY', 'timezone': {'timezone_identifier': 'America/New_York', 'timezone_abbr': 'EDT', 'utc_offset_sec': -14400, 'is_dst': 'T'}, 'acceptable_city_names': [], 'area_codes': [859]}
#
#
# Key=state value=KY

# %%
payload = {'zip_code': '40504', 'lat': 38.042391, 'lng': -84.543931, 'city': 'Lexington', 'state': 'KY', 'timezone': {'timezone_identifier': 'America/New_York', 'timezone_abbr': 'EDT', 'utc_offset_sec': -14400, 'is_dst': 'T'}, 'acceptable_city_names': [], 'area_codes': [859]}
print("\n")
print(payload)
print("\n")
#print(payload.state)
#print('\n largest number of students of Hawaii zip code= ', r['SPRADDR_ZIP_PR'])
for k, v in payload.items():
    if(k=="state"):
        print("Key={} value={}".format(k,v))
    else:
        pass
# Out:
# {'zip_code': '40504', 'lat': 38.042391, 'lng': -84.543931, 'city': 'Lexington', 'state': 'KY', 'timezone': {'timezone_identifier': 'America/New_York', 'timezone_abbr': 'EDT', 'utc_offset_sec': -14400, 'is_dst': 'T'}, 'acceptable_city_names': [], 'area_codes': [859]}
#
#
# Key=state value=KY

# %% [markdown]
# 2. assign a state code to the zip codes,

# %%
pip install pgeocode
# Out:
# Requirement already satisfied: pgeocode in c:\users\sh\anaconda3\lib\site-packages (0.2.1)
# Requirement already satisfied: numpy in c:\users\sh\anaconda3\lib\site-packages (from pgeocode) (1.16.5)
# Requirement already satisfied: requests in c:\users\sh\anaconda3\lib\site-packages (from pgeocode) (2.22.0)
# Requirement already satisfied: pandas in c:\users\sh\anaconda3\lib\site-packages (from pgeocode) (0.25.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\sh\anaconda3\lib\site-packages (from requests->pgeocode) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\sh\anaconda3\lib\site-packages (from requests->pgeocode) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\sh\anaconda3\lib\site-packages (from requests->pgeocode) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sh\anaconda3\lib\site-packages (from requests->pgeocode) (2019.9.11)
# Requirement already satisfied: pytz>=2017.2 in c:\users\sh\anaconda3\lib\site-packages (from pandas->pgeocode) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\sh\anaconda3\lib\site-packages (from pandas->pgeocode) (2.8.0)
# Requirement already satisfied: six>=1.5 in c:\users\sh\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas->pgeocode) (1.12.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pgeocode
nomi = pgeocode.Nominatim('us')
nomi.query_postal_code("13804")['state_code']
#
#nomi1 = pgeocode.Nominatim('us')
#nomi1.query_postal_code("40504")['state_code']
# Out:
# 'NY'

# %% [markdown]
# #OPTION THREE (EASIER): USE A STATIC FILE FROM GEONAMES.ORG

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 68FC-B994
#
#  Directory of C:\Users\sh\Desktop\USA\Rajanala\DataMining\mcis6273_f20_datamining-master\mcis6273_f20_datamining-master\homework\hw0
#
# 09/02/2020  01:48 AM    <DIR>          .
# 09/02/2020  01:48 AM    <DIR>          ..
# 08/31/2020  08:05 AM    <DIR>          .ipynb_checkpoints
# 09/02/2020  01:48 AM           133,742 123.ipynb
# 09/01/2020  10:08 PM               245 degrees.json
# 08/30/2020  05:08 AM         5,418,862 enrollment-by-zipcode.csv
# 09/02/2020  01:46 AM           833,219 hawaii_enrollments.csv
# 08/28/2020  02:24 PM            23,303 hw0.docx
# 08/28/2020  02:24 PM            33,871 hw0.html
# 09/02/2020  12:30 AM            55,775 hw0.ipynb
# 08/28/2020  02:24 PM            22,919 hw0.md
# 08/28/2020  02:24 PM           233,616 hw0.pdf
# 08/28/2020  02:24 PM               387 README.md
# 09/01/2020  03:19 AM         2,663,242 US.txt
# 09/02/2020  12:48 AM             1,010 zip_code_summary.csv
#               12 File(s)      9,420,191 bytes
#                3 Dir(s)  234,702,172,160 bytes free

# %%
import pandas as pd

# %%
df_zip = pd.read_csv("US.txt", header=None, sep='\t')

# %%
df_zip[ df_zip[1]==57641 ][4].item()
# Out:
# 'SD'

# %%
df_zip
# Out:
#        0      1           2       3    4               5     6    7   8   \
# 0      US  99553      Akutan  Alaska   AK  Aleutians East  13.0  NaN NaN
# 1      US  99571    Cold Bay  Alaska   AK  Aleutians East  13.0  NaN NaN
# 2      US  99583  False Pass  Alaska   AK  Aleutians East  13.0  NaN NaN
# 3      US  99612   King Cove  Alaska   AK  Aleutians East  13.0  NaN NaN
# 4      US  99661  Sand Point  Alaska   AK  Aleutians East  13.0  NaN NaN
# ...    ..    ...         ...     ...  ...             ...   ...  ...  ..
# 41465  US  96558      APO AA     NaN  NaN             NaN   NaN  NaN NaN
# 41466  US  96598      FPO AA     NaN  NaN             NaN   NaN  NaN NaN
# 41467  US  96599      FPO AA     NaN  NaN             NaN   NaN  NaN NaN
# 41468  US  96860      FPO AA     NaN  NaN             NaN   NaN  NaN NaN
# 41469  US  96863      FPO AA     NaN  NaN             NaN   NaN  NaN NaN
#
#             9         10   11
# 0      54.1430 -165.7854  1.0
# 1      55.1858 -162.7211  1.0
# 2      54.8542 -163.4113  1.0
# 3      55.0628 -162.3056  1.0
# 4      55.3192 -160.4914  1.0
# ...        ...       ...  ...
# 41465  19.7542 -155.5858  4.0
# 41466 -89.9976  139.2729  NaN
# 41467 -77.8460  166.6760  NaN
# 41468  21.3448 -157.9774  4.0
# 41469  21.4505 -157.7680  4.0
#
# [41470 rows x 12 columns]

# %%
df_zip[4].value_counts()
# Out:
# TX    2598
# CA    2591
# PA    2176
# NY    2153
# IL    1575
# FL    1473
# OH    1415
# VA    1214
# MI    1159
# MO    1156
# NC    1081
# IA    1055
# MN     991
# IN     967
# GA     952
# KY     946
# WI     896
# WV     851
# AL     811
# TN     785
# OK     764
# KS     747
# NJ     723
# LA     719
# WA     716
# AR     705
# MA     684
# CO     645
# NE     620
# MD     605
# SC     534
# MS     531
# AZ     528
# ME     485
# OR     478
# CT     429
# NM     427
# ND     407
# MT     404
# SD     385
# UT     346
# ID     320
# VT     308
# NH     281
# DC     277
# AK     273
# NV     253
# WY     195
# HI     137
# DE      96
# RI      90
# MH       2
# Name: 4, dtype: int64

# %% [markdown]
# 3. get an aggregate count of all enrollment numbers by state from 2014-2019.

# %% [markdown]
#  <b>$ Export that table to a CSV using DataFrame.to_csv('zip_code_summary.csv').</b>

# %%
import pandas as pd
data = pd.read_csv("enrollment-by-zipcode.csv")
data
# Out:
#         SEMESTER SPRADDR_ZIP_PR           IRO_INSTITUTION_DESCL  \
# 0      Fall 2012          96766        Kaua`i Community College
# 1      Fall 2012          96814    Kapi`olani Community College
# 2      Fall 2012          96792       Leeward Community College
# 3      Fall 2012          96822      Honolulu Community College
# 4      Fall 2012          96821    Kapi`olani Community College
# ...          ...            ...                             ...
# 87793  Fall 2019     96822-5703      Honolulu Community College
# 87794  Fall 2019     96817-1733      Honolulu Community College
# 87795  Fall 2019     96744-4205      Windward Community College
# 87796  Fall 2019     96822-4243  University of Hawai`i at Manoa
# 87797  Fall 2019          57103  University of Hawai`i at Manoa
#
#       HAWAIIAN_LEGACY  ENROLLMENT
# 0            HAWAIIAN          73
# 1                 NaN          19
# 2            HAWAIIAN         504
# 3                 NaN          12
# 4                 NaN          43
# ...               ...         ...
# 87793             NaN           1
# 87794             NaN           1
# 87795             NaN           1
# 87796             NaN           1
# 87797             NaN           1
#
# [87798 rows x 5 columns]

# %%
t_data=data.dropna()
len(t_data)
# Out:
# 14040

# %%
t_data.head(15)
# Out:
#      SEMESTER SPRADDR_ZIP_PR           IRO_INSTITUTION_DESCL HAWAIIAN_LEGACY  \
# 0   Fall 2012          96766        Kaua`i Community College        HAWAIIAN
# 2   Fall 2012          96792       Leeward Community College        HAWAIIAN
# 9   Fall 2012          96744      Windward Community College        HAWAIIAN
# 30  Fall 2012          96822  University of Hawai`i at Manoa        HAWAIIAN
# 35  Fall 2012          96790  University of Hawai`i at Manoa        HAWAIIAN
# 47  Fall 2012          96789      Honolulu Community College        HAWAIIAN
# 49  Fall 2012          96822      Honolulu Community College        HAWAIIAN
# 51  Fall 2012          96789       Leeward Community College        HAWAIIAN
# 54  Fall 2012          96819  University of Hawai`i at Manoa        HAWAIIAN
# 57  Fall 2012          96720   University of Hawai`i at Hilo        HAWAIIAN
# 62  Fall 2012          96762  University of Hawai`i at Manoa        HAWAIIAN
# 71  Fall 2012          96797       Leeward Community College        HAWAIIAN
# 78  Fall 2012          96825      Honolulu Community College        HAWAIIAN
# 86  Fall 2012          92867  University of Hawai`i at Manoa        HAWAIIAN
# 96  Fall 2012          93455   University of Hawai`i at Hilo        HAWAIIAN
#
#     ENROLLMENT
# 0           73
# 2          504
# 9          463
# 30         101
# 35          20
# 47          64
# 49          22
# 51          21
# 54           5
# 57          24
# 62          13
# 71           4
# 78          17
# 86           1
# 96           1

# %%
new = t_data["SEMESTER"].str.split(" ", n = 1, expand = True) 

t_data["YEAR"]= new[1]

# %%
t_data
# Out:
#         SEMESTER SPRADDR_ZIP_PR               IRO_INSTITUTION_DESCL  \
# 0      Fall 2012          96766            Kaua`i Community College
# 2      Fall 2012          96792           Leeward Community College
# 9      Fall 2012          96744          Windward Community College
# 30     Fall 2012          96822      University of Hawai`i at Manoa
# 35     Fall 2012          96790      University of Hawai`i at Manoa
# ...          ...            ...                                 ...
# 87779  Fall 2019     96706-4524  University of Hawai`i - West O`ahu
# 87784  Fall 2019     96789-2321           Leeward Community College
# 87785  Fall 2019          84047      University of Hawai`i at Manoa
# 87789  Fall 2019     96740-1524           Hawai`i Community College
# 87791  Fall 2019     96822-4921          Honolulu Community College
#
#       HAWAIIAN_LEGACY  ENROLLMENT  YEAR
# 0            HAWAIIAN          73  2012
# 2            HAWAIIAN         504  2012
# 9            HAWAIIAN         463  2012
# 30           HAWAIIAN         101  2012
# 35           HAWAIIAN          20  2012
# ...               ...         ...   ...
# 87779        HAWAIIAN           1  2019
# 87784        HAWAIIAN           1  2019
# 87785        HAWAIIAN           1  2019
# 87789        HAWAIIAN           1  2019
# 87791        HAWAIIAN           1  2019
#
# [14040 rows x 6 columns]

# %%
t_data.dtypes
# Out:
# SEMESTER                 object
# SPRADDR_ZIP_PR           object
# IRO_INSTITUTION_DESCL    object
# HAWAIIAN_LEGACY          object
# ENROLLMENT                int64
# YEAR                     object
# dtype: object

# %%
t_data['YEAR'] = t_data['YEAR'].astype(int)

# %%
t_data.dtypes
# Out:
# SEMESTER                 object
# SPRADDR_ZIP_PR           object
# IRO_INSTITUTION_DESCL    object
# HAWAIIAN_LEGACY          object
# ENROLLMENT                int64
# YEAR                      int32
# dtype: object

# %%
t_data = t_data[(t_data.YEAR >= 2014) & (t_data.YEAR <= 2019)]

# %%
len(t_data)
# Out:
# 10893

# %%
t_data = t_data[t_data.SPRADDR_ZIP_PR.map(str).map(len) == 5]
len(t_data)
# Out:
# 8228

# %%
#second process
df_zip = pd.read_csv("US.txt", header=None, sep='\t')
def getStateCode(k):
    try:
        k = df_zip[df_zip[1]==int(k)][4].item()
    except:
        pass
    return k

# %%
getStateCode(40504)
# Out:
# 'KY'

# %%
getStateCode(13804)
# Out:
# 'NY'

# %%
t_data['SPRADDR_ZIP_PR'] = t_data['SPRADDR_ZIP_PR'].astype(int).apply(getStateCode)

# %%
t_data['SPRADDR_ZIP_PR']
# Out:
# 2668     HI
# 2683     HI
# 2687     HI
# 2688     HI
# 2700     HI
#          ..
# 87667    CA
# 87669    HI
# 87741    CA
# 87778    HI
# 87785    UT
# Name: SPRADDR_ZIP_PR, Length: 8228, dtype: object

# %%
t_data.dtypes
# Out:
# SEMESTER                 object
# SPRADDR_ZIP_PR           object
# IRO_INSTITUTION_DESCL    object
# HAWAIIAN_LEGACY          object
# ENROLLMENT                int64
# YEAR                      int32
# dtype: object

# %%
t_data['SPRADDR_ZIP_PR'] = t_data['SPRADDR_ZIP_PR'].astype(str)
#t_data['SPRADDR_ZIP_PR'] = t_data['SPRADDR_ZIP_PR'][~t_data['SPRADDR_ZIP_PR'].str.isnumeric()]
t_data = t_data.dropna()
t_data.head()
# Out:
#        SEMESTER SPRADDR_ZIP_PR               IRO_INSTITUTION_DESCL  \
# 2668  Fall 2014             HI            Kaua`i Community College
# 2683  Fall 2014             HI  University of Hawai`i - West O`ahu
# 2687  Fall 2014             HI      University of Hawai`i at Manoa
# 2688  Fall 2014             HI           Leeward Community College
# 2700  Fall 2014             HI      University of Hawai`i at Manoa
#
#      HAWAIIAN_LEGACY  ENROLLMENT  YEAR
# 2668        HAWAIIAN         101  2014
# 2683        HAWAIIAN          59  2014
# 2687        HAWAIIAN         127  2014
# 2688        HAWAIIAN           4  2014
# 2700        HAWAIIAN         126  2014

# %%
len(t_data)
# Out:
# 8165

# %%
t_data['SPRADDR_ZIP_PR'][~t_data['SPRADDR_ZIP_PR'].str.isnumeric()]
# Out:
# 2668     HI
# 2683     HI
# 2687     HI
# 2688     HI
# 2700     HI
#          ..
# 87667    CA
# 87669    HI
# 87741    CA
# 87778    HI
# 87785    UT
# Name: SPRADDR_ZIP_PR, Length: 8165, dtype: object

# %%
t_data['SPRADDR_ZIP_PR'].str.isnumeric()
# Out:
# 2668     False
# 2683     False
# 2687     False
# 2688     False
# 2700     False
#          ...
# 87667    False
# 87669    False
# 87741    False
# 87778    False
# 87785    False
# Name: SPRADDR_ZIP_PR, Length: 8165, dtype: bool

# %%
len(t_data['SPRADDR_ZIP_PR'].str.isnumeric())
# Out:
# 8165

# %%
t_data.dtypes
# Out:
# SEMESTER                 object
# SPRADDR_ZIP_PR           object
# IRO_INSTITUTION_DESCL    object
# HAWAIIAN_LEGACY          object
# ENROLLMENT                int64
# YEAR                      int32
# dtype: object

# %%
t_data = t_data.dropna()

# %%
len(t_data)
# Out:
# 8228

# %%
list1= t_data['SPRADDR_ZIP_PR'].str.isnumeric()

# %%
type(list1)
# Out:
# pandas.core.series.Series

# %%
#t_data['SPRADDR_ZIP_PR'] = t_data['SPRADDR_ZIP_PR'][~t_data['SPRADDR_ZIP_PR'].str.isnumeric()]

# %%
len(t_data)
# Out:
# 8165

# %%
nan_value = float("NaN")

#Convert NaN values to empty string

t_data.replace("", nan_value, inplace=True)


t_data.dropna(subset = ["SPRADDR_ZIP_PR"], inplace=True)
t_data = t_data.dropna()

# %%
len(t_data)
# Out:
# 8165

# %%
t_data
# Out:
#         SEMESTER SPRADDR_ZIP_PR               IRO_INSTITUTION_DESCL  \
# 2668   Fall 2014             HI            Kaua`i Community College
# 2683   Fall 2014             HI  University of Hawai`i - West O`ahu
# 2687   Fall 2014             HI      University of Hawai`i at Manoa
# 2688   Fall 2014             HI           Leeward Community College
# 2700   Fall 2014             HI      University of Hawai`i at Manoa
# ...          ...            ...                                 ...
# 87667  Fall 2019             CA      University of Hawai`i at Manoa
# 87669  Fall 2019             HI        Kapi`olani Community College
# 87741  Fall 2019             CA  University of Hawai`i Maui College
# 87778  Fall 2019             HI  University of Hawai`i Maui College
# 87785  Fall 2019             UT      University of Hawai`i at Manoa
#
#       HAWAIIAN_LEGACY  ENROLLMENT  YEAR
# 2668         HAWAIIAN         101  2014
# 2683         HAWAIIAN          59  2014
# 2687         HAWAIIAN         127  2014
# 2688         HAWAIIAN           4  2014
# 2700         HAWAIIAN         126  2014
# ...               ...         ...   ...
# 87667        HAWAIIAN           1  2019
# 87669        HAWAIIAN           1  2019
# 87741        HAWAIIAN           1  2019
# 87778        HAWAIIAN           1  2019
# 87785        HAWAIIAN           1  2019
#
# [8165 rows x 6 columns]

# %%
#set_index('Locality', inplace=True)

# %% [markdown]
# # 1. get an aggregate count of all enrollment numbers by state from 2014-2019.

# %%
y=t_data['SPRADDR_ZIP_PR'].value_counts()

# %%
y
# Out:
# HI     6326
# CA     1045
# WA      191
# OR       72
# NV       43
# TX       43
# AK       39
# AZ       34
# CO       32
# UT       29
# GA       23
# MI       23
# VA       23
# TN       20
# NY       19
# FL       17
# MD       16
# NJ       16
# nan      16
# NC       15
# AR       13
# ID       13
# PA       11
# MO        9
# IL        8
# MN        8
# WI        7
# MA        6
# NM        5
# SC        5
# ME        4
# OK        4
# WV        4
# OH        3
# IA        3
# NE        3
# IN        2
# DE        2
# CT        2
# MH        2
# SD        2
# NH        2
# VT        1
# AL        1
# ND        1
# KS        1
# MT        1
# Name: SPRADDR_ZIP_PR, dtype: int64

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
y.sort_values()
# Out:
# MT        1
# VT        1
# KS        1
# ND        1
# AL        1
# NH        2
# SD        2
# MH        2
# CT        2
# DE        2
# IN        2
# OH        3
# NE        3
# IA        3
# WV        4
# OK        4
# ME        4
# SC        5
# NM        5
# MA        6
# WI        7
# MN        8
# IL        8
# MO        9
# PA       11
# ID       13
# AR       13
# NC       15
# nan      16
# NJ       16
# MD       16
# FL       17
# NY       19
# TN       20
# GA       23
# VA       23
# MI       23
# UT       29
# CO       32
# AZ       34
# AK       39
# TX       43
# NV       43
# OR       72
# WA      191
# CA     1045
# HI     6326
# Name: SPRADDR_ZIP_PR, dtype: int64

# %%
import pandas as pd

# %%
len(t_data['ENROLLMENT'].value_counts())
# Out:
# 191

# %%
t_data['SPRADDR_ZIP_PR'].sort_values()
# Out:
# 39977     AK
# 76131     AK
# 14341     AK
# 40761     AK
# 3870      AK
#         ...
# 36955    nan
# 36956    nan
# 75647    nan
# 20558    nan
# 69267    nan
# Name: SPRADDR_ZIP_PR, Length: 8165, dtype: object

# %%
t_data['SPRADDR_ZIP_PR'].sort_values().tail(17)
# Out:
# 70129     WV
# 75762    nan
# 47523    nan
# 60720    nan
# 84123    nan
# 70107    nan
# 81109    nan
# 46814    nan
# 59321    nan
# 19605    nan
# 85511    nan
# 72693    nan
# 36955    nan
# 36956    nan
# 75647    nan
# 20558    nan
# 69267    nan
# Name: SPRADDR_ZIP_PR, dtype: object

# %%
t_data['SPRADDR_ZIP_PR'].value_counts().plot(kind='bar')

# %%
#t_data['SPRADDR_ZIP_PR'].
group_zip_count = t_data.groupby('SPRADDR_ZIP_PR').count()

# %%
len(group_zip_count)
# Out:
# 47

# %%
group_zip_count.head(15)
# Out:
#                 SEMESTER  IRO_INSTITUTION_DESCL  HAWAIIAN_LEGACY  ENROLLMENT  \
# SPRADDR_ZIP_PR
# AK                    39                     39               39          39
# AL                     1                      1                1           1
# AR                    13                     13               13          13
# AZ                    34                     34               34          34
# CA                  1045                   1045             1045        1045
# CO                    32                     32               32          32
# CT                     2                      2                2           2
# DE                     2                      2                2           2
# FL                    17                     17               17          17
# GA                    23                     23               23          23
# HI                  6326                   6326             6326        6326
# IA                     3                      3                3           3
# ID                    13                     13               13          13
# IL                     8                      8                8           8
# IN                     2                      2                2           2
#
#                 YEAR
# SPRADDR_ZIP_PR
# AK                39
# AL                 1
# AR                13
# AZ                34
# CA              1045
# CO                32
# CT                 2
# DE                 2
# FL                17
# GA                23
# HI              6326
# IA                 3
# ID                13
# IL                 8
# IN                 2

# %%
group_zip_count = group_zip_count.reset_index()

group_zip_count[['SPRADDR_ZIP_PR','ENROLLMENT']]
# Out:
#    SPRADDR_ZIP_PR  ENROLLMENT
# 0              AK          39
# 1              AL           1
# 2              AR          13
# 3              AZ          34
# 4              CA        1045
# 5              CO          32
# 6              CT           2
# 7              DE           2
# 8              FL          17
# 9              GA          23
# 10             HI        6326
# 11             IA           3
# 12             ID          13
# 13             IL           8
# 14             IN           2
# 15             KS           1
# 16             MA           6
# 17             MD          16
# 18             ME           4
# 19             MH           2
# 20             MI          23
# 21             MN           8
# 22             MO           9
# 23             MT           1
# 24             NC          15
# 25             ND           1
# 26             NE           3
# 27             NH           2
# 28             NJ          16
# 29             NM           5
# 30             NV          43
# 31             NY          19
# 32             OH           3
# 33             OK           4
# 34             OR          72
# 35             PA          11
# 36             SC           5
# 37             SD           2
# 38             TN          20
# 39             TX          43
# 40             UT          29
# 41             VA          23
# 42             VT           1
# 43             WA         191
# 44             WI           7
# 45             WV           4
# 46            nan          16

# %% [markdown]
# <h3> § Export that table to a CSV using DataFrame.to_csv('zip_code_summary.csv').</h3>

# %%
group_zip_count.to_csv('zip_code_summary.csv')

# %% [markdown]
# <h3>§ Plot the top 15 (non-Hawaii) states by enrollment:</h3>

# %%
#x = group_zip_count.groupby('SPRADDR_ZIP_PR')['ENROLLMENT'].mean().sort_values().tail(15)
group_zip_count.groupby('SPRADDR_ZIP_PR')['ENROLLMENT'].mean()
# Out:
# SPRADDR_ZIP_PR
# AK       39
# AL        1
# AR       13
# AZ       34
# CA     1045
# CO       32
# CT        2
# DE        2
# FL       17
# GA       23
# HI     6326
# IA        3
# ID       13
# IL        8
# IN        2
# KS        1
# MA        6
# MD       16
# ME        4
# MH        2
# MI       23
# MN        8
# MO        9
# MT        1
# NC       15
# ND        1
# NE        3
# NH        2
# NJ       16
# NM        5
# NV       43
# NY       19
# OH        3
# OK        4
# OR       72
# PA       11
# SC        5
# SD        2
# TN       20
# TX       43
# UT       29
# VA       23
# VT        1
# WA      191
# WI        7
# WV        4
# nan      16
# Name: ENROLLMENT, dtype: int64

# %%
zip_sorting_values= group_zip_count.groupby('SPRADDR_ZIP_PR')['ENROLLMENT'].mean().sort_values()
type(zip_sorting_values)
# Out:
# pandas.core.series.Series

# %%
# drop the passed labels 
result = zip_sorting_values.drop(labels = ['HI'])  
  
# Print the result 
print(result)
# Out:
# SPRADDR_ZIP_PR
# MT        1
# AL        1
# ND        1
# VT        1
# KS        1
# MH        2
# IN        2
# NH        2
# CT        2
# SD        2
# DE        2
# OH        3
# IA        3
# NE        3
# WV        4
# OK        4
# ME        4
# NM        5
# SC        5
# MA        6
# WI        7
# MN        8
# IL        8
# MO        9
# PA       11
# ID       13
# AR       13
# NC       15
# nan      16
# MD       16
# NJ       16
# FL       17
# NY       19
# TN       20
# MI       23
# VA       23
# GA       23
# UT       29
# CO       32
# AZ       34
# AK       39
# TX       43
# NV       43
# OR       72
# WA      191
# CA     1045
# Name: ENROLLMENT, dtype: int64

# %%
#non_Hawaii_states_grap=zip_sorting_values.drop("HI")
#non_Hawaii_states_grap=zip_sorting_values.drop("nan")
#non_Hawaii_states_grap

# %%
PlotTop15Grap=result.tail(15)

# %%
PlotTop15Grap.plot(kind='bar')

# %%
import matplotlib.pyplot as plt
import pandas as pd

# a simple line plot
PlotTop15Grap.plot(kind='bar',x='Non-Hawaii States',y='Total Enrollment')
